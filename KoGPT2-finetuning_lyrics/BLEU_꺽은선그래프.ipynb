# %%
from matplotlib import pyplot as plt
plt.plot([1, 2, 3], [0.58, 0.31, 0.13], label="IU")
plt.plot([1, 2, 3], [0.52, 0.28, 0.14], label="Sunwoojunga")
plt.plot([1, 2, 3], [0.37, 0.20, 0.11], label="MonstaX")
plt.xticks([1,2,3], labels=['1-gram', '2-gram', '3-gram'])
plt.xlabel('IU')
plt.ylabel('BLEU Score')
plt.legend() 
plt.show()

# %%
from matplotlib import pyplot as plt
plt.plot([1, 2, 3], [0.54, 0.27, 0.10], label="IU")
plt.plot([1, 2, 3], [0.55, 0.30, 0.15], label="Sunwoojunga")
plt.plot([1, 2, 3], [0.43, 0.24, 0.13], label="MonstaX")
plt.xticks([1,2,3], labels=['1-gram', '2-gram', '3-gram'])
plt.xlabel('Sunwoojunga')
plt.ylabel('BLEU Score')
plt.legend() 
plt.show()

# %%
from matplotlib import pyplot as plt
plt.plot([1, 2, 3], [0.60, 0.29, 0.13], label="IU")
plt.plot([1, 2, 3], [0.58, 0.32, 0.16], label="Sunwoojunga")
plt.plot([1, 2, 3], [0.47, 0.31, 0.21], label="MonstaX")
plt.xticks([1,2,3], labels=['1-gram', '2-gram', '3-gram'])
plt.xlabel('MonstaX')
plt.ylabel('BLEU Score')
plt.legend() 
plt.show()
