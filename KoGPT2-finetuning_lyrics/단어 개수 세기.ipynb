# %%
from collections import Counter
 
f = open('dataset/아이유_lyrics.tsv', 'r', encoding='utf-8') 
# d드라이브의 mobydick.txt라는 파일을 불러옴
# encoding = "utf-8"은 불러온 파일의 한글이 깨지지 않게 함
 
count = Counter(f.read().split()) # 파일을 불러와 단어 단위로 split(자른) 수를 세어 count 변수에 저장
print("단어 출력 횟수 : ", count) # 출력
# Out:
# 단어 출력 횟수 :  Counter({'그': 160, '내': 139, 'you': 115, '더': 87, '한': 81, 'love': 79, '날': 75, '이': 71, '다': 69, '수': 63, '난': 63, 'I': 62, 'my': 58, '나를': 50, '안': 46, '나': 45, '또': 44, 'the': 44, 'is': 44, '없는': 42, '다시': 42, '내가': 39, '것': 39, '두': 38, '나의': 38, '게': 38, '있는': 38, '네': 37, '못': 36, '꼭': 35, '왜': 35, 'a': 34, 'me': 33, 'need': 33, '널': 32, '모든': 32, '너의': 31, '없이': 31, '너를': 29, '사랑': 29, '같은': 28, 'My': 28, '손을': 28, 'your': 27, 'for': 27, '보고': 27, '정말': 27, 'Oh': 25, 'all': 25, '눈을': 24, '너무': 24, 'tak': 24, '우리': 23, '잘': 23, 'oh': 23, '말': 23, '넌': 23, 'so': 23, '수가': 22, '않는': 22, '하는': 22, '건': 22, '사람': 22, '하나': 22, '좀': 22, '가득': 22, '그렇게': 21, '걸': 21, 'know': 21, '내게': 21, '다른': 20, '봐': 20, '저': 20, 'baby': 20, '밤': 19, '마음': 19, '않을': 19, '속에': 19, '눈': 19, '위에': 19, '사랑이': 19, '너만': 19, '아라에': 19, '다닿을까': 19, '눈이': 18, 'to': 18, '나는': 18, '작은': 18, '커다란': 18, '그대': 18, 'day': 18, '할': 17, 'sweet': 17, '아닌': 17, '눈물이': 17, 'first': 17, 'like': 16, '맘을': 
# ...

# %%
from collections import Counter
 
f = open('dataset/몬스타엑스_lyrics.tsv', 'r', encoding='utf-8') 
 
words_몬스타엑스 = f.read().split() # 파일을 불러와 단어 단위로 split(자른) 수를 세어 count 변수에 저장
type(words_몬스타엑스)
# Out:
# list

# %%
import pandas as pd
df = pd.DataFrame.from_records(list(dict(count).items()), columns=['word','num'])

# %%
df['num'].sum()
# Out:
# 16675

# %%
from collections import Counter
 
f = open('dataset/itzy_lyrics.tsv', 'r', encoding='utf-8') 
# d드라이브의 mobydick.txt라는 파일을 불러옴
# encoding = "utf-8"은 불러온 파일의 한글이 깨지지 않게 함
 
count = Counter(f.read().split()) # 파일을 불러와 단어 단위로 split(자른) 수를 세어 count 변수에 저장
print("단어 출력 횟수 : ", count) # 출력
# Out:
# 단어 출력 횟수 :  Counter({'me': 100, 'I': 76, 'like': 71, 'you': 70, 'a': 64, 'uh': 64, '원해': 63, '다': 60, '난': 58, 'La': 58, 'TING': 51, '달라': 44, 'ya': 42, '더': 41, 'wanna': 40, 'your': 40, 'be': 39, 'it': 38, '날': 35, '내': 35, 'up': 34, 'my': 34, 'what': 32, 'no': 31, "don't": 31, 'love': 30, 'on': 29, 'the': 28, 'make': 28, '널': 28, 'ID': 28, 'Not': 25, 'Wild': 23, 'hey': 22, 'nobody': 22, 'yeah': 22, 'to': 22, "I'm": 21, 'we': 21, '내가': 21, '네': 20, 'not': 20, 'pa': 20, '안': 19, 'give': 19, 'shy': 19, 'DDA': 19, '건': 18, '여름': 18, 'ma': 18, '봐': 18, 'and': 18, '뭔가': 18, 'keep': 18, 'that': 17, '하지': 16, '걸': 16, '넌': 16, '볼래': 16, '완전': 16, '깨': 15, '좀': 15, 'meI’m': 15, 'for': 14, '수': 13, 'gonna': 13, '게': 13, 'do': 13, 'kidding': 13, '와': 13, '우리': 13, 'really': 13, 'cherry': 13, '나를': 12, 'meI': 12, '지금': 12, '몰래같이': 12, '신나게놀아': 12, '그냥': 11, '있지': 11, 'top': 11, '거야': 11, '해': 11, 'We': 11, '똑바로': 11, 'this': 11, '말': 11, '다다': 11, 'shyNot': 11, 'Blah': 11, 'LA': 11, 'don’t': 1
# ...

# %%
from collections import Counter
 
f = open('dataset/itzy_lyrics.tsv', 'r', encoding='utf-8') 
 
words_itzy = f.read().split() # 파일을 불러와 단어 단위로 split(자른) 수를 세어 count 변수에 저장
type(words)
# Out:
# list

# %%
import pandas as pd
df = pd.DataFrame.from_records(list(dict(count).items()), columns=['word','num'])

# %%
df['num'].sum()
# Out:
# 6446

# %%
import numpy as np

np.array(df['word'].tolist())
# Out:
# array(['lyrics', 'okay', 'ay', ..., 'beatand', 'lose', '원해진짤'],
#       dtype='<U34')

# %%
list_itzy=list(np.array(df['word'].tolist()))

# %%
import re
reg = re.compile(r'[a-zA-Z]')
num_korean=0
num_english=0
for i in list_itzy:

    if reg.match(i):
        num_english+=1
    else:
        num_korean+=1

# %%
print(num_korean, num_english)
# Out:
# 1317 954

# %%
from collections import Counter
import pandas as pd

f = open('dataset/아이유_lyrics.tsv', 'r', encoding='utf-8') 
# d드라이브의 mobydick.txt라는 파일을 불러옴
# encoding = "utf-8"은 불러온 파일의 한글이 깨지지 않게 함
 
count = Counter(f.read().split()) # 파일을 불러와 단어 단위로 split(자른) 수를 세어 count 변수에 저장

df_아이유 = pd.DataFrame.from_records(list(dict(count).items()), columns=['word','num'])
df_아이유
# Out:
#            word  num
# 0        lyrics    1
# 1            무얼    4
# 2         고를까추운    2
# 3     겨울이니까캐시미어    2
# 4          스웨터는    2
# ...         ...  ...
# 7353       불러보고    1
# 7354   웃음질때머리맡에    1
# 7355     울고그대만을    1
# 7356       웃어주는    1
# 7357      설레이는이    1
#
# [7358 rows x 2 columns]

# %%
df_아이유['num'].sum()
# Out:
# 16675

# %%
from collections import Counter
import pandas as pd

f = open('dataset/루시드폴_lyrics.tsv', 'r', encoding='utf-8') 
# d드라이브의 mobydick.txt라는 파일을 불러옴
# encoding = "utf-8"은 불러온 파일의 한글이 깨지지 않게 함
 
count = Counter(f.read().split()) # 파일을 불러와 단어 단위로 split(자른) 수를 세어 count 변수에 저장

df_루시드폴 = pd.DataFrame.from_records(list(dict(count).items()), columns=['word','num'])
df_루시드폴
# Out:
#          word  num
# 0      lyrics    1
# 1         시간이    4
# 2          벌써    3
# 3      이렇게겨울을    1
# 4         데리고    7
# ...       ...  ...
# 3716    있는데나를    1
# 3717    둘러싼나를    1
# 3718    제외한모든    1
# 3719     사람들은    1
# 3720  즐겁다사람들은    2
#
# [3721 rows x 2 columns]

# %%
df_루시드폴['num'].sum() # 루시드폴
# Out:
# 7378

# %%
from collections import Counter
import pandas as pd

f = open('dataset/노라조_lyrics.tsv', 'r', encoding='utf-8') 
# d드라이브의 mobydick.txt라는 파일을 불러옴
# encoding = "utf-8"은 불러온 파일의 한글이 깨지지 않게 함
 
count = Counter(f.read().split()) # 파일을 불러와 단어 단위로 split(자른) 수를 세어 count 변수에 저장

df_노라조 = pd.DataFrame.from_records(list(dict(count).items()), columns=['word','num'])
df_노라조
# Out:
#                                               word  num
# 0                                           lyrics    1
# 1                                              고기를    1
# 2                                               먹을    4
# 3                                               때는    3
# 4                                               상추    1
# ...                                            ...  ...
# 4574                                            한국    1
# 4575  한국-간주중-오오오오오오오오오오오오오오오오오대한민국오오오오오오오오오오오오오오오자    1
# 4576                                      대한민국대한민국    2
# 4577                                          파이팅온    1
# 4578                                       없도다대한민국    1
#
# [4579 rows x 2 columns]

# %%
df_노라조['num'].sum()
# Out:
# 10756

# %%
from collections import Counter
import pandas as pd

f = open('dataset/몬스타엑스_lyrics.tsv', 'r', encoding='utf-8') 
# d드라이브의 mobydick.txt라는 파일을 불러옴
# encoding = "utf-8"은 불러온 파일의 한글이 깨지지 않게 함
 
count = Counter(f.read().split()) # 파일을 불러와 단어 단위로 split(자른) 수를 세어 count 변수에 저장

df_몬스타엑스 = pd.DataFrame.from_records(list(dict(count).items()), columns=['word','num'])
df_몬스타엑스
# Out:
#            word  num
# 0        lyrics    1
# 1          (Hey    1
# 2           hey   11
# 3      hey)분위기는    1
# 4            위기    1
# ...         ...  ...
# 10393    second    1
# 10394     터지는불꽃    1
# 10395   하이라이트몸에    1
# 10396      순위야영    1
# 10397       순위야    1
#
# [10398 rows x 2 columns]

# %%
df_몬스타엑스['num'].sum()
# Out:
# 31073

# %%
from collections import Counter

word_num = 0
with open('dataset/itzy_lyrics.tsv', 'r', encoding='utf-8') as f:
    words = [w.strip('.,') for w in f.read().split()]
    for w, c in Counter(words).most_common(150):
        if len(w)!=1:
            word_num += 1
            print(w, c)
print(word_num)
# Out:
# me 100
# like 71
# you 70
# uh 64
# 원해 63
# La 58
# TING 51
# 달라 44
# ya 42
# wanna 40
# your 40
# be 39
# it 38
# up 34
# my 34
# what 32
# no 31
# don't 31
# love 30
# on 29
# the 28
# make 28
# ID 28
# Not 25
# Wild 23
# hey 22
# nobody 22
# yeah 22
# to 22
# I'm 21
# we 21
# 내가 21
# not 20
# pa 20
# give 19
# shy 19
# DDA 19
# 여름 18
# ma 18
# and 18
# 뭔가 18
# keep 18
# that 17
# 하지 16
# 볼래 16
# 완전 16
# meI’m 15
# for 14
# gonna 13
# do 13
# kidding 13
# 우리 13
# really 13
# cherry 13
# 나를 12
# meI 12
# 지금 12
# 몰래같이 12
# 신나게놀아 12
# 그냥 11
# 있지 11
# top 11
# 거야 11
# We 11
# 똑바로 11
# this 11
# 다다 11
# shyNot 11
# Blah 11
# LA 11
# don’t 10
# 따라 10
# ah 10
# go 10
# stop 10
# 해Stop 10
# right 10
# TING멋대로 10
# summerIt’s 10
# myself난 10
# 진짤 10
# 높이 9
# I’m 9
# 하고 9
# one 9
# 알고 9
# in 9
# 뻔한 8
# You 8
# can 8
# got 8
# Nah 8
# 많아 8
# know 8
# just 8
# 맘을 8
# ITZY난 8
# 어때 8
# whatLa 8
# TINGFEEL대로 8
# pum 8
# 좋아 8
# 마난 8
# 없는 7
# get 7
# 나는 7
# 하는 7
# 보여줄 7
# feel 7
# 보고 7
# 너무 7
# ...

# %%
from collections import Counter
word_num = 0
with open('dataset/아이유_lyrics.tsv', 'r', encoding='utf-8') as f:
    words = [w.strip('.,') for w in f.read().split()]
    for w, c in Counter(words).most_common(100):
        if len(w)!=1:
            word_num += 1
            print(w, c)
print(word_num)
# Out:
# you 115
# love 79
# my 58
# 나를 51
# the 44
# is 44
# 없는 42
# 다시 42
# 내가 39
# 나의 38
# 있는 38
# me 33
# need 33
# 모든 32
# 너의 31
# 없이 31
# 너를 29
# 사랑 29
# 같은 28
# My 28
# 손을 28
# your 27
# for 27
# 보고 27
# 정말 27
# Oh 25
# all 25
# 눈을 24
# 너무 24
# tak 24
# 우리 23
# oh 23
# so 23
# 수가 22
# 않는 22
# 하는 22
# 사람 22
# 하나 22
# 가득 22
# 그렇게 21
# know 21
# 내게 21
# 다른 20
# baby 20
# 마음 19
# 않을 19
# 속에 19
# 위에 19
# 사랑이 19
# 너만 19
# 아라에 19
# 다닿을까 19
# 눈이 18
# to 18
# 나는 18
# 작은 18
# 커다란 18
# 그대 18
# day 18
# sweet 17
# 아닌 17
# 눈물이 17
# first 17
# like 16
# 맘을 16
# la 16
# 아직 16
# 67

# %%
from collections import Counter

with open('dataset/루시드폴_lyrics.tsv', 'r', encoding='utf-8') as f:
    words = [w.strip('.,') for w in f.read().split()]
    for w, c in Counter(words).most_common(120):
        if len(w)!=1:
            print(w, c)
# Out:
# 나를 66
# 되는 43
# 있는 31
# 나의 30
# 다시 29
# 없는 27
# 그대 25
# 내가 24
# 눈이 21
# 같은 21
# 이렇게 21
# 우리 20
# 너무 20
# 않는 20
# 있을 18
# 가을 18
# 눈을 15
# 멀리 15
# 못한 14
# 나는 14
# 내게 14
# 없이 13
# 하나 13
# 여름 13
# is 12
# 너의 12
# 아무리 12
# 죄인으로 12
# 너무나 11
# 노래를 11
# 있나요당신은 11
# 우릴 10
# 당신 10
# 함께 10
# 깊은 10
# 아무 10
# 나도 10
# 사는 10
# 걷다 9
# 모두 9
# 되어 9
# 작은 9
# 그렇게바다처럼 9
# 보고 9
# 그렇게 9
# 하늘의 9
# 날개를 9
# 날개가 9
# 모든 8
# 살고 8
# 않은 8
# 말을 8
# 보이지 8
# 얘기 8
# 흘러 8
# 만든 8
# 보이게 8
# 데리고 7
# 내리는 7
# 말도 7
# 겨울 7
# 비가 7
# 몸을 7
# 같이 7
# 싶은 7
# 울고 7
# 어느 7
# 손을 7
# 노래 7
# 하늘 7
# 정말 7
# 하루가 7
# 그대는 7
# 수만 7
# 떠나기 7
# 나나나나나나나나나 7
# 그대로네제자리 7
# 많은 6
# Merry 6
# 기다릴 6
# okEverything 6
# 부르는 6
# 너와 6
# 바람 6
# always 6
# wait 6
# for 6
# 보면길이 6
# 길이 6
# 잠이 6

# %%
from collections import Counter

with open('dataset/몬스타엑스_lyrics.tsv', 'r', encoding='utf-8') as f:
    words = [w.strip('.,') for w in f.read().split()]
    for w, c in Counter(words).most_common(50):
        if len(w)!=1:
            print(w, c)
# Out:
# you 312
# it 258
# me 192
# my 172
# the 131
# up 131
# oh 129
# your 128
# be 126
# can 116
# to 111
# love 105
# 너의 97
# la 93
# wanna 89
# for 85
# or 82
# and 82
# go 81
# so 78
# na 75
# we 74
# 나를 73
# 없어 72
# like 72
# 니가 72
# 없는 70
# baby 70
# 모든 69
# 나의 69
# 너를 68
# 내게 68
# 없이 67
# know 65
# all 64
# 우린 63

# %%
from collections import Counter

with open('dataset/노라조_lyrics.tsv', 'r', encoding='utf-8') as f:
    words = [w.strip('.,') for w in f.read().split()]
    for w, c in Counter(words).most_common(50):
        if len(w)!=1:
            print(w, c)
# Out:
# 먹고 66
# 먹다 63
# 빵빵 60
# 뱃속이 57
# 빵빵빵빵빵빵 55
# 나를 47
# 대박 37
# 든든해 36
# 빵빵빵빵 34
# 가루 32
# 빵빵빵 31
# 시간 29
# 우유를 29
# 한잔빵 29
# 밀가루 27
# 배신하지 27
# 내가 27
# 반죽은치대고 26
# 치대면 26
# 뻑뻑하면 26
# 너무달아 26
# 커피를 26
# 말고 26
# 부풀어 25
# 오르고오랜 25
# 손맛은우리를 25
# 넣었으면 24
# 씹어 24
# 먹다보면살살 24
# 정신 24
# 줄을 24
# 샐러드도발라버려 23
# 어울려빵 23
# 한잔꼭꼭 22
# 녹아버린다빵빵빵빵 22
# 공공칠 22
# 달려라 22

# %%
def word_count(text):
    wordAll=text.split(' ')
    wordDic={}
    for i in wordAll:
        wordCnt=wordAll.count(i);
        wordDic[i]=wordCnt
    
    print("\n당신이 입력하신 문장의 단어수는 아래와 같습니다.\n")

    for cnts in wordDic:
        print(cnts," : ",wordDic[cnts])

    return

word_count('나를 부를 때 나는 왜 숨을 쉬지 못하고 비틀거리는 거야 눈물이 멈추질 않아서 잠시만 가만히 있으면 눈을 뜨면 눈을 뜨지 않아 꺼져 있는 꿈속을 바라보면서 나도 모르게 눈물이 흘러 나오고 마음을 다 비우면 나 혼자만의 방으로 들어가서 잠시만 가만히 있으면 눈을 뜨지 않아')
# Out:
# 당신이 입력하신 문장의 단어수는 아래와 같습니다.
#
# 나를  :  1
# 부를  :  1
# 때  :  1
# 나는  :  1
# 왜  :  1
# 숨을  :  1
# 쉬지  :  1
# 못하고  :  1
# 비틀거리는  :  1
# 거야  :  1
# 눈물이  :  2
# 멈추질  :  1
# 않아서  :  1
# 잠시만  :  2
# 가만히  :  2
# 있으면  :  2
# 눈을  :  3
# 뜨면  :  1
# 뜨지  :  2
# 않아  :  2
# 꺼져  :  1
# 있는  :  1
# 꿈속을  :  1
# 바라보면서  :  1
# 나도  :  1
# 모르게  :  1
# 흘러  :  1
# 나오고  :  1
# 마음을  :  1
# 다  :  1
# 비우면  :  1
# 나  :  1
# 혼자만의  :  1
# 방으로  :  1
# 들어가서  :  1

# %%
from collections import Counter
import pandas as pd

f = open('dataset/아이유_lyrics.tsv', 'r', encoding='utf-8') 
# d드라이브의 mobydick.txt라는 파일을 불러옴
# encoding = "utf-8"은 불러온 파일의 한글이 깨지지 않게 함
 
count = Counter(f.read().split()) # 파일을 불러와 단어 단위로 split(자른) 수를 세어 count 변수에 저장

df_노라조 = pd.DataFrame.from_records(list(dict(count).items()), columns=['word','num'])
df_노라조
# Out:
#            word  num
# 0        lyrics    1
# 1            무얼    4
# 2         고를까추운    2
# 3     겨울이니까캐시미어    2
# 4          스웨터는    2
# ...         ...  ...
# 7353       불러보고    1
# 7354   웃음질때머리맡에    1
# 7355     울고그대만을    1
# 7356       웃어주는    1
# 7357      설레이는이    1
#
# [7358 rows x 2 columns]

# %%
df_노라조['num'].sum()
# Out:
# 16675

# %%
from collections import Counter
import pandas as pd

f = open('dataset/선우정아_lyrics.tsv', 'r', encoding='utf-8') 
# d드라이브의 mobydick.txt라는 파일을 불러옴
# encoding = "utf-8"은 불러온 파일의 한글이 깨지지 않게 함
 
count = Counter(f.read().split()) # 파일을 불러와 단어 단위로 split(자른) 수를 세어 count 변수에 저장

df_노라조 = pd.DataFrame.from_records(list(dict(count).items()), columns=['word','num'])
df_노라조
# Out:
#          word  num
# 0      lyrics    1
# 1         아침이    1
# 2         밝아올    5
# 3        때까지내    6
# 4           몸    7
# ...       ...  ...
# 5054  하늘이지만다시    1
# 5055      또다시    1
# 5056     안녕이젠    1
# 5057      영원히    1
# 5058       안녕    1
#
# [5059 rows x 2 columns]

# %%
df_노라조['num'].sum()
# Out:
# 12770
